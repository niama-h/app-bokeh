# %% [markdown]
# ### Choix de Dataset
# On a choisi le dataset sur le chômage au Maroc pour plusieurs raisons importantes. Tout d'abord, dans notre région Beni Mellal-Khénifra le chômage très répandu, c'est un indicateur crucial qui affecte directement la qualité de vie des citoyens et la stabilité économique du pays. En étudiant ces données, on peut identifier les tendances et les disparités régionales, de plus,le Maroc fait face à des défis spécifiques,notamment le chômage des jeunes et des diplômés,rendant cette analyse particulièrement pertinente .
# (https://www.data.gov.ma/))
# .

# %%
import pandas as pd 
df0=pd.read_csv("data1.csv")
df0
# Out:
#     CODE Milieu de résidence       Durée de chômage       Sexe  1999  2000  \
# 0    482              Urbain       Moins de 12 mois  Masculin     26  26,8
# 1    486              Urbain       Moins de 12 mois    Feminin  20,4  20,9
# 2    478              Urbain       Moins de 12 mois      Total  24,3  25,1
# 3    483              Urbain  12 à moins de 36 mois  Masculin   27,7  26,7
# 4    487              Urbain  12 à moins de 36 mois    Feminin  28,8  29,4
# 5    479              Urbain  12 à moins de 36 mois      Total    28  27,5
# 6    484              Urbain  36 à moins de 60 mois  Masculin   17,5  16,5
# 7    488              Urbain  36 à moins de 60 mois    Feminin  20,2  20,3
# 8    480              Urbain  36 à moins de 60 mois      Total  18,3  17,6
# 9    485              Urbain        60 mois et plus  Masculin   28,6  29,9
# 10   489              Urbain        60 mois et plus    Feminin  30,6  29,4
# ...

# %%
df0.shape
# Out:
# (36, 27)

# %%
len(df0)
# Out:
# 36

# %%
df0.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36 entries, 0 to 35
# Data columns (total 27 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   CODE                 36 non-null     int64
#  1   Milieu de résidence  36 non-null     object
#  2   Durée de chômage     36 non-null     object
#  3   Sexe                 36 non-null     object
#  4   1999                 36 non-null     object
#  5   2000                 36 non-null     object
#  6   2001                 36 non-null     object
#  7   2002                 36 non-null     object
#  8   2003                 36 non-null     object
#  9   2004                 36 non-null     object
#  10  2005                 36 non-null     float64
#  11  2006                 36 non-null     float64
#  12  2007                 36 non-null     float64
#  13  2008                 36 non-null     float64
#  14  2009                 36 non-null     float64
# ...

# %%
df0.describe()
# Out:
#              CODE       2005       2006       2007       2008       2009  \
# count   36.000000  36.000000  36.000000  36.000000  36.000000  36.000000
# mean   477.500000  24.630556  24.991667  24.933333  24.994444  24.952778
# std     10.535654  10.272788  11.601709  10.626033   8.932155   9.773243
# min    460.000000   9.100000   8.000000  10.700000  10.400000  11.000000
# 25%    468.750000  16.900000  14.725000  16.700000  18.350000  18.025000
# 50%    477.500000  24.500000  25.150000  24.500000  25.900000  24.100000
# 75%    486.250000  30.000000  30.225000  29.100000  29.050000  30.700000
# max    495.000000  55.600000  56.300000  54.300000  50.600000  51.700000
#
#             2010       2011       2012       2013       2014       2015  \
# count  36.000000  36.000000  36.000000  36.000000  36.000000  36.000000
# mean   24.838889  25.069444  24.913889  25.094444  24.902778  24.958333
# std    10.961811  10.043813  10.841195  12.246048  12.255366  11.113554
# ...

# %%
df1=pd.read_csv("data3.csv")
df1
# Out:
#      Indicateurs sociaux - Emploi activité et chômage 2002-08    2008    2009  \
# 0        Activité, emploi et chômage (15 ans et plus)     NaN     NaN     NaN
# 1      Population active 15 ans et plus (En milliers)  10,849  11,267  11,314
# 2                                              Urbain   5,532   5,874   5,916
# 3                                               Rural   5,318   5,393   5,398
# 4   Structure de la population active selon les gr...     NaN     NaN     NaN
# ..                                                ...     ...     ...     ...
# 75                                  Niveau supérieur     23.5    20.6    19.1
# 76                                   Ayant un diplôme    23.7    19.0    17.8
# 77     Taux de chômage rural selon le diplôme  (En %)     NaN     NaN     NaN
# 78                                       Sans diplôme     2.4     2.6     2.5
# 79                                   Ayant un diplôme    11.6    12.2    11.8
#
# ...

# %%
df1.shape
# Out:
# (80, 8)

# %%
len(df1)
# Out:
# 80

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 80 entries, 0 to 79
# Data columns (total 8 columns):
#  #   Column                                            Non-Null Count  Dtype
# ---  ------                                            --------------  -----
#  0   Indicateurs sociaux - Emploi activité et chômage  79 non-null     object
#  1   2002-08                                           64 non-null     object
#  2   2008                                              64 non-null     object
#  3   2009                                              64 non-null     object
#  4   2010                                              64 non-null     object
#  5   2011                                              64 non-null     object
#  6   2012                                              64 non-null     object
#  7   2013                                              64 non-null     object
# dtypes: object(8)
# memory usage: 5.1+ KB

# %%
df1.describe()
# Out:
#        Indicateurs sociaux - Emploi activité et chômage 2002-08  2008  2009  \
# count                                                79      64    64    64
# unique                                               36      63    61    60
# top                                              Urbain     3.6  14.7  11.8
# freq                                                  8       2     3     2
#
#         2010   2011    2012  2013
# count     64     64      64    64
# unique    60     63      64    62
# top     20.2  5,237  11,549  18.4
# freq       2      2       1     2

# %%
df2=pd.read_csv("data2.csv")
df2
# Out:
#      CODE Milieu de résidence  \
# 0   11164              Urbain
# 1   11165              Urbain
# 2   11170              Urbain
# 3   11171              Urbain
# 4   11175              Urbain
# 5   11177              Urbain
# 6   11179              Urbain
# 7   11184              Urbain
# 8   11166               Rural
# 9   11167               Rural
# 10  11172               Rural
# 11  11173               Rural
# 12  11178               Rural
# 13  11180               Rural
# 14  11182               Rural
# 15  11186               Rural
# 16  11168            National
# 17  11169            National
# 18  11174            National
# 19  11176            National
# 20  11181            National
# 21  11183            National
# 22  11185            National
# 23  11163            National
#
#                                               Diplôme  1999  2000  2001  2002  \
# 0   Diplôme et certificat de l’enseignement fondam...  29,2  29,7  26,1  24,1
# ...

# %% [markdown]
# #### On elimine les colonnes dont les valeurs sont NULL

# %%
for i in range(1996,1999):
    df0.drop(str(i),axis=1, inplace=True)

# %%
df0
# Out:
#     CODE Milieu de résidence       Durée de chômage       Sexe  1999  2000  \
# 0    482              Urbain       Moins de 12 mois  Masculin     26  26,8
# 1    486              Urbain       Moins de 12 mois    Feminin  20,4  20,9
# 2    478              Urbain       Moins de 12 mois      Total  24,3  25,1
# 3    483              Urbain  12 à moins de 36 mois  Masculin   27,7  26,7
# 4    487              Urbain  12 à moins de 36 mois    Feminin  28,8  29,4
# 5    479              Urbain  12 à moins de 36 mois      Total    28  27,5
# 6    484              Urbain  36 à moins de 60 mois  Masculin   17,5  16,5
# 7    488              Urbain  36 à moins de 60 mois    Feminin  20,2  20,3
# 8    480              Urbain  36 à moins de 60 mois      Total  18,3  17,6
# 9    485              Urbain        60 mois et plus  Masculin   28,6  29,9
# 10   489              Urbain        60 mois et plus    Feminin  30,6  29,4
# ...

# %%
df2.drop('1977', axis=1, inplace=True)

# %%
for i in range(1978,1999):
    df2.drop(str(i),axis=1, inplace=True)

# %%
df2
# Out:
#      CODE Milieu de résidence  \
# 0   11164              Urbain
# 1   11165              Urbain
# 2   11170              Urbain
# 3   11171              Urbain
# 4   11175              Urbain
# 5   11177              Urbain
# 6   11179              Urbain
# 7   11184              Urbain
# 8   11166               Rural
# 9   11167               Rural
# 10  11172               Rural
# 11  11173               Rural
# 12  11178               Rural
# 13  11180               Rural
# 14  11182               Rural
# 15  11186               Rural
# 16  11168            National
# 17  11169            National
# 18  11174            National
# 19  11176            National
# 20  11181            National
# 21  11183            National
# 22  11185            National
# 23  11163            National
#
#                                               Diplôme  1999  2000  2001  2002  \
# 0   Diplôme et certificat de l’enseignement fondam...  29,2  29,7  26,1  24,1
# ...

# %%
df2.shape
# Out:
# (24, 26)

# %%
df2.describe()
# Out:
#                CODE       2010       2011       2012       2013       2014  \
# count     24.000000  24.000000  24.000000  24.000000  24.000000  24.000000
# mean   11174.500000  17.270833  17.241667  16.025000  15.720833  17.354167
# std        7.071068   8.485460   8.746672   7.199049   8.543545   8.839633
# min    11163.000000   2.400000   2.300000   2.300000   2.400000   2.700000
# 25%    11168.750000  12.625000  12.375000  12.300000   8.975000  11.925000
# 50%    11174.500000  17.350000  18.000000  17.700000  16.600000  17.550000
# 75%    11180.250000  20.650000  20.175000  20.600000  19.750000  21.875000
# max    11186.000000  34.000000  35.100000  32.900000  41.000000  41.000000
#
#            2015       2016       2017       2018       2019       2020  \
# count  24.00000  24.000000  24.000000  24.000000  24.000000  24.000000
# mean   17.38750  17.733333  17.904167  17.000000  16.304167  19.375000
# std     8.03126   9.303700   8.508997   8.688223   8.285004   8.963416
# ...

# %%
len(df2)
# Out:
# 24

# %%
df0.to_csv('data1.csv',index=False)

# %%
df1.to_csv('data3.csv',index=False)

# %%
df2.to_csv('data2.csv',index=False)

# %% [markdown]
# on filtre pour choisir les deux sexe et le niveau national

# %%
import pandas as pd
df=pd.read_csv('data1.csv')
dff=df[df['Milieu de résidence']=='National'] 
dff=dff[dff['Sexe']=='Total'] 
dff
# Out:
#     CODE Milieu de résidence       Durée de chômage   Sexe  1999  2000  2001  \
# 26   466            National       Moins de 12 mois  Total  28,4  29,9  30,9
# 29   467            National  12 à moins de 36 mois  Total  27,3  26,5  25,6
# 32   468            National  36 à moins de 60 mois  Total  17,5  16,7  16,8
# 35   469            National        60 mois et plus  Total  26,7  26,8  26,6
#
#     2002  2003  2004  ...  2012  2013  2014  2015  2016  2017  2018  2019  \
# 26  30,5  29,4  30,3  ...  34.5  35.8  37.9  13.2  32.6  28.6  32.1  31.8
# 29  25,4    24  25,8  ...  26.0  27.3  28.1  34.5  32.7  33.2  32.2  31.0
# 32  16,2  15,7  14,6  ...  14.7  13.7  13.0  34.5  14.5  15.8  32.3  17.4
# 35  27,9    31  29,2  ...  24.3  23.0  20.6  21.6  19.9  22.2  32.4  21.4
#
#     2020  2021
# 26  43.7  27.5
# 29  28.2  41.9
# 32  12.8  14.3
# 35  15.2  16.3
#
# [4 rows x 27 columns]
